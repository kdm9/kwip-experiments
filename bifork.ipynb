# %%
from utils import *

# %% [markdown]
# Make a random genome, and 16 samples derived from it. Write it to a fasta file.

# %%
genome = make_rand_genome(mbp=10)

# %%
bifork = biforcating_sequences(genome, levels=3, av_rate=0.0001, sd_rate=0.00001)
seqlist = list(flatten(bifork))
# Out:
# at level 3 (a rate: 0.000100697466883 b rate: 9.74286909335e-05 )
# at level 2 (a rate: 8.6747073157e-05 b rate: 0.000107356945888 )
# at level 1 (a rate: 0.000118853323653 b rate: 9.42411377269e-05 )
# at level 0 (a rate: 8.43455903423e-05 b rate: 8.14192346377e-05 )
# at level 0 (a rate: 9.99827264131e-05 b rate: 9.26661239649e-05 )
# at level 1 (a rate: 0.000102459375258 b rate: 0.000119223687305 )
# at level 0 (a rate: 9.76065478592e-05 b rate: 9.73274082312e-05 )
# at level 0 (a rate: 0.00010901203441 b rate: 9.17842873453e-05 )
# at level 2 (a rate: 0.000109973139425 b rate: 0.000122244703802 )
# at level 1 (a rate: 0.00012702280605 b rate: 8.96868130666e-05 )
# at level 0 (a rate: 8.78185314429e-05 b rate: 0.000100214570037 )
# at level 0 (a rate: 0.000103313185379 b rate: 0.000105602197992 )
# at level 1 (a rate: 9.55072082673e-05 b rate: 0.000103549906651 )
# at level 0 (a rate: 0.00010947091139 b rate: 0.000101712249864 )
# at level 0 (a rate: 0.000117462564835 b rate: 9.72193253752e-05 )

# %%
with open("bifork_10mb.fas", 'w') as fh:
    print_multifasta(seqlist, file=fh)

# %% [markdown]
# ## Make NJ tree

# %%
from skbio import Alignment, DNA
from skbio.tree import nj

# %%
aln = Alignment.read('bifork_10mb.fas')

# %%
distmat = aln.distances()

# %%
distmat

# %%
tree = nj(distmat)

# %%
tree.write('bifork_10mb.nwk')

# %%
print(tree.ascii_art())
# Out:
#                               /-8
#                     /--------|
#                    |          \-7
#           /--------|
#          |         |          /-6
#          |          \--------|
#          |                    \-5
#          |
#          |                    /-2
#          |          /--------|
#          |         |          \-1
#          |---------|
#          |         |          /-4
# ---------|          \--------|
#          |                    \-3
#          |
#          |                              /-14
#          |                    /--------|
#          |                   |          \-13
#          |          /--------|
#          |         |         |          /-16
#          |         |          \--------|
#          |         |                    \-15
#           \--------|
#                    |                    /-10
#                    |          /--------|
#                    |         |          \-9
#                     \--------|
#                              |          /-12
#                               \--------|
#                                         \-11
