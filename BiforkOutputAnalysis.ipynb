# %%
from skbio import DistanceMatrix
from skbio.tree import nj

# %%
import ete3

# %%
from ete3 import Tree

# %%
kwip_dist = DistanceMatrix.read("data/bifork.dist")
kwip_dist

# %%
kwip_tree = nj(kwip_dist)
kwip_tree.write('data/bifork_kwip.nwk')
# Out:
# 'data/bifork_kwip.nwk'

# %%
true_tree = Tree("data/bifork_runs.nwk")
kwip_tree = Tree("data/bifork_kwip.nwk")

# %%
# Out:
# [0, 0, set(), set(), set(), set(), set()]

# %% [markdown]
# ## Hierarchical clustering
#
# And ploting by matplotlib

# %% [markdown]
# # Tree files
# [true tree](data/bifork_runs.nwk)
# [kwip tree](data/bifork_kwip.nwk)
